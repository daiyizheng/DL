# %% [markdown]
# # match-case 语句
#
# ## 一、MATCH-CASE语句的基本用法
# Python的match-case语句是一种模式匹配结构，允许根据表达式的结果执行不同的代码块。其基本语法结构如下：
#
# ```python
# match variable:
#     case pattern1:
#         # 执行代码块1
#     case pattern2:
#         # 执行代码块2
#     case _:
#         # 默认执行代码块
# ```

# %% [markdown]
# 在这个结构中，variable是需要匹配的变量，而pattern1、pattern2等是可以匹配的模式。当variable与某个pattern匹配成功时，执行对应的代码块。如果没有匹配成功，则执行case _中的代码块。

# %% [markdown]
# ## 替代复杂的条件判断
# 在处理多个条件判断时，match-case语句可以作为if-elif-else结构的替代方案，提高代码的可读性。例如：
#
# ```python
#
# def get_day_name(day_num):
#     match day_num:
#         case 1:
#             return "Monday"
#         case 2:
#             return "Tuesday"
#         case 3:
#             return "Wednesday"
#         case 4:
#             return "Thursday"
#         case 5:
#             return "Friday"
#         case 6:
#             return "Saturday"
#         case 7:
#             return "Sunday"
#         case _:
#             return "Invalid day"
# ```

# %% [markdown]
# ## 处理复杂的数据结构
# 在处理复杂的数据结构，如嵌套的列表或字典时，match-case语句可以通过模式匹配简化代码逻辑。例如：

# %%
data = ("John", {"age": 30, "job": "Engineer"})
match data:
    case (name, {"age": age, "job": job}):
        print(f"{name} is a {age} years old {job}")
