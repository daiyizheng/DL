# %% [markdown]
# # 自定义
# ## 一般的
#
# ### 定制模型
#
#
# ### 自定义超时、重试和其他
#
#
# ## 指标
# ### 修改指标中的提示
# ### 编写您自己的指标
# ### 使指标适应目标语言
# ### 使用可观察性工具跟踪评估
# ### 训练和校准指标
#
# ## 测试集生成
# ### 从非英语语料库生成测试数据
# ### 配置或自动生成角色
# ### 自定义单跳查询以进行 RAG 评估
# ### 为 RAG 评估创建自定义多跳查询
# ### 使用生产数据进行种子生成
